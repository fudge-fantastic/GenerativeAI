# %%
import os
import dotenv
from groq import Groq
from IPython.display import display_markdown

dotenv.load_dotenv()
api_key = os.environ.get("GROQ_API_KEY")

if not api_key:
    raise ValueError("GROQ_API_KEY environment variable not set")

# %%
def get_llama_assistance(prompt):
  client = Groq(api_key=api_key)
  completion = client.chat.completions.create(
      model="llama3-70b-8192",
      messages=[
          {
              "role": "user",
              "content": prompt
          },
          {
              "role": "assistant",
              "content": ""
          }
      ],
      temperature=1.4,
      max_tokens=8192,
      top_p=1,
      stream=True,
      stop=None,
  )

  response_text = ""

  for chunk in completion:
    response_text += chunk.choices[0].delta.content or ""

  # Display the formatted response in markdown
  display_markdown(f"`\n{response_text}\n`", raw=True)

# %%
from docx import Document

def extract_text_from_docx(docx_file_path):
    doc = Document(docx_file_path)
    text_content = []
    for paragraph in doc.paragraphs:
        # Remove leading and trailing spaces from each line
        line = paragraph.text.strip()
        if line:  # Check if line is not empty after stripping
            text_content.append(line)
    return '\n'.join(text_content)

docx_file_path = 'ICR Agreement .docx'
extracted_text = extract_text_from_docx(docx_file_path)
print(extracted_text)
# Out:
# ELIGIBILITY TO APPLY TO IMARTICUS CORPORATE RELATIONS (ICR)
# 1. Students are eligible for placements post-completion of level 2 of the curriculum (Final Mock) or by formal signoff by the faculty and/or program managers
# 2. Trainers will certify students for placement eligibility based on
# Assessment scores
# Mock interviews
# Viva scores
# Soft Skills Trainer sign-off
# Resume Readiness
# Overall, all discipline and conduct
# 3. Minimum overall attendance should be 80%. Students below 80% attendance will not be eligible for placements
# 4. Students should indemnify any administrative formalities and get a clearance from the Imarticus Administration and Finance department.
# AGREEMENT FOR PLACEMENT ASSISTANCE
# This agreement is made on Imarticus Placement Platform: SuperSet
# THIS AGREEMENT, between IMARTICUS and THE STUDENT, witnesses the mutual understanding and acceptance of the following terms
# IMARTICUS will provide the ICR Service to the Student via the SuperSet platform. Emails/mobile notifications and SMS will be sent to the registered email address & mobile number.
# The Student is solely responsible for continuously monitoring the SuperSet account to check positions /vacancies posted by IMARTICUS.
# To apply to the job openings students should log in to their SuperSet account through Laptop/desktop or Mobile App.
# Opportunities will be posted in the Job profile section of SuperSet.
# Each Student from the Placement Assured Program will be given five interview opportunities. If the student fails to be placed after 5 such attempts, he/she needs to go through an assessment and post clearing the assessment only will be rolled out in the placement pool again. For placement assistance programs we will be sharing public and private leads for job assistance
# A student who applies for a position and then backs out at any stage of the process without prior approval from the Placement team will be barred from placements
# A Student who is a “NO SHOW” at any scheduled interview will be barred from applying for any future job opportunities
# The Student is expected to conduct himself/herself ethically. Unethical behaviour such as cheating during the selection process or misrepresentation of facts in a resume will disqualify the student from placement
# As soon as the student receives the offer of employment with an Organization via the ICR service, the ICR service will be considered fulfilled and this contract will expire.
# Post the final mock if a particular student has been graded in T3, he/she doesn’t have an option to apply to the companies of their choice and will have to abide by the drives offered to them. However, a student has an option of improving their grades after another mock (Limited to 2).
# The Student can contact the placement coordinator of the Centre where he/she completed the course whenever he/she requires any clarification about the Organization or the Vacancy
# It shall be the responsibility of the Student to attend the interview on her/his own. Imarticus has no control over the outcome of the interview/selection process. Imarticus shall not be held responsible in the event the Student gets disqualified for selection for any vacancy, whatsoever the reason
# Upon receipt of an offer of employment, the Student will immediately inform IMARTICUS regarding details of her /his appointment and acceptance thereof
# In the event the student has not applied for any position for two months after signing the ICR, they will be contacted by email and phone at least twice to confirm their continued participation in the placement program. In the event of no response or confirmation from the student within three weeks, attempts will be made to contact the student again after which a registered letter will be sent to the permanent address of the Student terminating this contract
# In availing the ICR Service, the student hereby agrees and undertakes that during the period of this agreement and up to a minimum of 18 months from the day and date of signing of this agreement, he/she shall not: -
# (i) Defame IMARTICUS directly or indirectly and/or make any verbal, written or oral statements which can be construed as derogatory/defamatory pertaining to ‘IMARTICUS’ and the ‘COURSES’ conducted by ‘IMARTICUS’
# (ii) Share Course material, manuals, books and or photocopies of the same and/or disclose the same in any other manner, whatsoever to any other person (other than IMARTICUS’s students), organisation, firm, company or any other entity
# (iii) Start competitive activities either himself or through his family members, which includes but is not limited to similar business as that of ‘IMARTICUS’ directly, indirectly or in any manner,  in India and/or Abroad
# (iv) Disclose to any other person, (other than ‘IMARTICUS’s Students) or organisation, firm, company or any entity, whosoever, any information received by him/her from ‘IMARTICUS’ as part of ‘ Assistance Services provided by ‘IMARTICUS CORPORATE RELATIONS”, which includes Offer details, Salary figures but not limited to job vacancies in Investment Banks, KPO’s and other niche organizations in the BFSI domain
# (v) Indulge in any anti ‘IMARTICUS’ activity, whatsoever.
# 16. The original copy of this agreement shall be retained by “IMARTICUS”
# 17. This Agreement shall be construed and interpreted by the laws of India.
# Date :	9th May 2024
# Place:	India, Maharashtra, Pune
# Name :	Aaditya Pandagle
# Permanent Address:	Indrayani HSC Society, Rupeenagar, Talawade-Road, Nigdi-Pune
# Batch No:	PG-WD-47
# Signature :

# %%
cwd = os.getcwd()
path1 = os.path.dirname(cwd)
poppler_path = os.path.join(path1, 'Gemini', 'poppler-24.02.0', 'Library', 'bin')
print(poppler_path)
logs_path = os.path.join(os.getcwd(), 'Logs')
print(logs_path)
# Out:
# d:\CODING\Generative-AI\LLama\Gemini\poppler-24.02.0\Library\bin
# d:\CODING\Generative-AI\LLama\Résumé\Logs

# %%
# !pip install pdfquery
# !pip install pdfplumber

# %%
import pdfplumber
import re

def clean_text(text):
    # Remove extra newlines and leading/trailing whitespace
    text = re.sub(r'\n\s*\n', '\n\n', text)  # Replace multiple newlines with a single newline
    text = text.strip()  # Remove leading and trailing whitespace
    return text

path = r'Templates\AP_Resume_2024.pdf'

with pdfplumber.open(path) as pdf:
    all_text = ""
    for page in pdf.pages:
        text = page.extract_text()
        if text:
            all_text += text + "\n\n"
            
all_text = clean_text(all_text)
print(all_text)
print(len(all_text))
# Out:
# Work and Projects
# A a d i t y a
# You can explore my GitHub profile where I’ve performed statistical analysis and created
# predictive models. The portfolio spans various topics such as:
# P a n d a g l e
# Machine Learning:
# Data Science | AI & Machine Learning | Fraud Detection: Identify fraudulent activities within financial transactions using ML
# MLOps | Generative-AI algorithms on authentic datasets.
# Credit Risk Assessment: Assessing credit risk for loan applicants using predictive
# modelling.
# House Rent Prediction: Using machine learning algorithms to predict house rent
# Contact:
# prices in India.
# Customer Discount Offering Prediction: Predict which customers will likely receive
# adi.pandagle@gmail.com
# discounts for targeted marketing.
# +91 79725 67926 Deep Learning:
# American Sign Language Detection: Developed a model to recognize and interpret
# LinkedIn and GitHub link
# American Sign Language gestures for communication accessibility.
# Generative-AI:
# Education:
# OCR-Gemini: Leveraged Tesseract for invoice text extraction and Gemini for data
# structuring the extracted data into JSON format.
# Post Graduation Program in Data Science Resume-JD Analyzer: Implementing data extraction methods to input data into
# and Analytics - Imarticus Learning (Pune) LLama3, facilitating analysis of both job descriptions (JD) and resumes.
# (2023 - 2024) Query-Builder: Utilizing PostgreSQL as the database backend, extracting key
# content, and seamlessly integrating it into LLama3 for query generation and
# Bachelors' in Business Administration execution.
# (Computer Application) Modern College of
# Others:
# Commerce & Computer Studies; Savitribai
# Django: Utilized Django to create a web-based diabetes prediction model.
# Phule Pune University Affiliated.
# MLOps Sandbox: MLOps Integration Testing (Docker, Jenkins, CI/CD)
# (2020 - 2023) CGPA - 8.61
# Skills & Hobbies
# Senior Secondary School - PDEA's Shri
# Mhalsakant Vidyalaya & Jr. College.
# Machine Learning and Deep Learning:
# (2018 - 2020) - 55.69%
# Supervised Learning: (Linear & Logistics Regression, SVM, Decision-Tree and
# Ensembles) Unsupervised Learning (K-Means, Hierarchical Clustering, and
# High School - S.P.M English Medium
# Dimensionality Reduction-Principal Component Analysis)
# School, Nigdi-Pune. Neural Networks (ANN, CNN and RNN), NLP, and DL Frameworks
# (2007 - 2018) - 69.00% (TensorFlow and Keras)
# Data Science:
# Data Analysis & Visualization, Statistical Analysis & Modeling, Feature
# Auxilary Skills: Engineering & Optimization Techniques.
# MLOps:
# DSA (Basics) MLflow, Packaging, Version Control (Git), Docker, Jenkins, Prometheus and
# CI/CD Pipeline.
# Cloud (AWS)
# Web Development, Programming Languages & Databases:
# Deep Learning (Fundamentals)
# Flask, FastAPI, Django, Data Structures & Algorithms (DSA), Python and
# Packaging & Containerization MySQL
# Version Control & CI/CD (Basics) Cloud: Amazon Web Services (EC2, S3, SageMaker, and others)
# Hobbies
# LLMs (Gemini and LLama)
# Avid Reader, Artist (sketching figures and objects)
# Collaborative and Adaptability Strategic Chess Player, Video/Board Games, Coding.
# Problem-solving and Inquisitive Listening and Creating Lo-fi tracks for fun on YouTube
# Certifications and Achievemnets
# Languages:
# Udemy: Python for Data Science and Machine Learning Bootcamp
# English
# Kaggle - Beginner and Intermediate Machine Learning
# Hindi and Marathi (Native)
# HackerRank - SQL Basic and Intermediate
# German and Japanese (Novice)
# Udemy: Python Data Structures and Algorithm
# Udemy: Amazon Web Services - Solution Architect.
# Ranked 1st in chess competitions during both the 2nd and 3rd years of my
# academic journey.
# 3580

# %%
path = r'Templates\AP_Resume_2024.pdf'

with pdfplumber.open(path) as pdf:
  all_text = ""
  # Below is for storing the extracted data in list 
  extracted_text = []
  for page in pdf.pages:
    all_text += page.extract_text() + "\n\n"
    extracted_text.append(page.extract_text()) 

print(all_text)
print(len(all_text))
# Out:
# Work and Projects
# A a d i t y a
# You can explore my GitHub profile where I’ve performed statistical analysis and created
# predictive models. The portfolio spans various topics such as:
# P a n d a g l e
# Machine Learning:
# Data Science | AI & Machine Learning | Fraud Detection: Identify fraudulent activities within financial transactions using ML
# MLOps | Generative-AI algorithms on authentic datasets.
# Credit Risk Assessment: Assessing credit risk for loan applicants using predictive
# modelling.
# House Rent Prediction: Using machine learning algorithms to predict house rent
# Contact:
# prices in India.
# Customer Discount Offering Prediction: Predict which customers will likely receive
# adi.pandagle@gmail.com
# discounts for targeted marketing.
# +91 79725 67926 Deep Learning:
# American Sign Language Detection: Developed a model to recognize and interpret
# LinkedIn and GitHub link
# American Sign Language gestures for communication accessibility.
# Generative-AI:
# Education:
# OCR-Gemini: Leveraged Tesseract for invoice text extraction and Gemini for data
# structuring the extracted data into JSON format.
# Post Graduation Program in Data Science Resume-JD Analyzer: Implementing data extraction methods to input data into
# and Analytics - Imarticus Learning (Pune) LLama3, facilitating analysis of both job descriptions (JD) and resumes.
# (2023 - 2024) Query-Builder: Utilizing PostgreSQL as the database backend, extracting key
# content, and seamlessly integrating it into LLama3 for query generation and
# Bachelors' in Business Administration execution.
# (Computer Application) Modern College of
# Others:
# Commerce & Computer Studies; Savitribai
# Django: Utilized Django to create a web-based diabetes prediction model.
# Phule Pune University Affiliated.
# MLOps Sandbox: MLOps Integration Testing (Docker, Jenkins, CI/CD)
# (2020 - 2023) CGPA - 8.61
# Skills & Hobbies
# Senior Secondary School - PDEA's Shri
# Mhalsakant Vidyalaya & Jr. College.
# Machine Learning and Deep Learning:
# (2018 - 2020) - 55.69%
# Supervised Learning: (Linear & Logistics Regression, SVM, Decision-Tree and
# Ensembles) Unsupervised Learning (K-Means, Hierarchical Clustering, and
# High School - S.P.M English Medium
# Dimensionality Reduction-Principal Component Analysis)
# School, Nigdi-Pune. Neural Networks (ANN, CNN and RNN), NLP, and DL Frameworks
# (2007 - 2018) - 69.00% (TensorFlow and Keras)
# Data Science:
# Data Analysis & Visualization, Statistical Analysis & Modeling, Feature
# Auxilary Skills: Engineering & Optimization Techniques.
# MLOps:
# DSA (Basics) MLflow, Packaging, Version Control (Git), Docker, Jenkins, Prometheus and
# CI/CD Pipeline.
# Cloud (AWS)
# Web Development, Programming Languages & Databases:
# Deep Learning (Fundamentals)
# Flask, FastAPI, Django, Data Structures & Algorithms (DSA), Python and
# Packaging & Containerization MySQL
# Version Control & CI/CD (Basics) Cloud: Amazon Web Services (EC2, S3, SageMaker, and others)
# Hobbies
# LLMs (Gemini and LLama)
# Avid Reader, Artist (sketching figures and objects)
# Collaborative and Adaptability Strategic Chess Player, Video/Board Games, Coding.
# Problem-solving and Inquisitive Listening and Creating Lo-fi tracks for fun on YouTube
# Certifications and Achievemnets
# Languages:
# Udemy: Python for Data Science and Machine Learning Bootcamp
# English
# Kaggle - Beginner and Intermediate Machine Learning
# Hindi and Marathi (Native)
# HackerRank - SQL Basic and Intermediate
# German and Japanese (Novice)
# Udemy: Python Data Structures and Algorithm
# Udemy: Amazon Web Services - Solution Architect.
# Ranked 1st in chess competitions during both the 2nd and 3rd years of my
# academic journey.
#
#
# 3582

# %%
extracted_text
# Out:
# ["Work and Projects\nA a d i t y a\nYou can explore my GitHub profile where I’ve performed statistical analysis and created\npredictive models. The portfolio spans various topics such as:\nP a n d a g l e\nMachine Learning:\nData Science | AI & Machine Learning | Fraud Detection: Identify fraudulent activities within financial transactions using ML\nMLOps | Generative-AI algorithms on authentic datasets.\nCredit Risk Assessment: Assessing credit risk for loan applicants using predictive\nmodelling.\nHouse Rent Prediction: Using machine learning algorithms to predict house rent\nContact:\nprices in India.\nCustomer Discount Offering Prediction: Predict which customers will likely receive\nadi.pandagle@gmail.com\ndiscounts for targeted marketing.\n+91 79725 67926 Deep Learning:\nAmerican Sign Language Detection: Developed a model to recognize and interpret\nLinkedIn and GitHub link\nAmerican Sign Language gestures for communication accessibility.\nGenerative-AI:\nEducation:\nOCR-Gemini: Leveraged Tesseract for invoice text extraction and Gemini for data\nstructuring the extracted data into JSON format.\nPost Graduation Program in Data Science Resume-JD Analyzer: Implementing data extraction methods to input data into\nand Analytics - Imarticus Learning (Pune) LLama3, facilitating analysis of both job descriptions (JD) and resumes.\n(2023 - 2024) Query-Builder: Utilizing PostgreSQL as the database backend, extracting key\ncontent, and seamlessly integrating it into LLama3 for query generation and\nBachelors' in Business Administration execution.\n(Computer Application) Modern College of\nOthers:\nCommerce & Computer Studies; Savitribai\nDjango: Utilized Django to create a web-based diabetes prediction model.\nPhule Pune University Affiliated.\nMLOps Sandbox: MLOps Integration Testing (Docker, Jenkins, CI/CD)\n(2020 - 2023) CGPA - 8.61\nSkills & Hobbies\nSenior Secondary School - PDEA's Shri\nMhalsakant Vidyalaya & Jr. College.\nMachine Learning and Deep Learning:\n(2018 - 2020) - 55.69%\nSupervised Learning: (Linear & Logistics Regression, SVM, Decision-Tree and\nEnsembles) Unsupervised Learning (K-Means, Hierarchical Clustering, and\nHigh School - S.P.M English Medium\nDimensionality Reduction-Principal Component Analysis)\nSchool, Nigdi-Pune. Neural Networks (ANN, CNN and RNN), NLP, and DL Frameworks\n(2007 - 2018) - 69.00% (TensorFlow and Keras)\nData Science:\nData Analysis & Visualization, Statistical Analysis & Modeling, Feature\nAuxilary Skills: Engineering & Optimization Techniques.\nMLOps:\nDSA (Basics) MLflow, Packaging, Version Control (Git), Docker, Jenkins, Prometheus and\nCI/CD Pipeline.\nCloud (AWS)\nWeb Development, Programming Languages & Databases:\nDeep Learning (Fundamentals)\nFlask, FastAPI, Django, Data Structures & Algorithms (DSA), Python and\nPackaging & Containerization MySQL\nVersion Control & CI/CD (Basics) Cloud: Amazon Web Services (EC2, S3, SageMaker, and others)\nHobbies\nLLMs (Gemini and LLama)\nAvid Reader, Artist (sketching figures and objects)\nCollaborative and Adaptability Strategic Chess Player, Video/Board Games, Coding.\nProblem-solving and Inquisitive Listening and Creating Lo-fi tracks for fun on YouTube\nCertifications and Achievemnets\nLanguages:\nUdemy: Python for Data Science and Machine Learning Bootcamp\nEnglish\nKaggle - Beginner and Intermediate Machine Learning\nHindi and Marathi (Native)\nHackerRank - SQL Basic and Intermediate\nGerman and Japanese (Novice)\nUdemy: Python Data Structures and Algorithm\nUdemy: Amazon Web Services - Solution Architect.\nRanked 1st in chess competitions during both the 2nd and 3rd years of my\nacademic journey."]

# %%
get_llama_assistance(f'''I need your help to organize the Resume text, I extracted from a PDF and review:
                    {all_text}''')
# Out:
# `
# I've reorganized your resume text to make it easier to read and understand. Here's the revised version:
#
# **Summary**
#
# Explore my GitHub profile for statistical analysis and predictive modeling projects on various topics, including machine learning, data science, and fraud detection.
#
# **Education**
#
# * Post-Graduation Program in Data Science and Analytics, Imarticus Learning (Pune) (2023 - 2024)
# * Bachelor's in Business Administration (Computer Application), Modern College of Commerce & Computer Studies; Savitribai Phule Pune University Affiliated. (2020 - 2023), CGPA - 8.61
# * Senior Secondary School, PDEA's Shri. Mhalsakant Vidyalaya & Jr. College. (2018 - 2020), 55.69%
# * High School, S.P.M English Medium School, Nigdi-Pune. (2007 - 2018), 69.00%
#
# **Technical Skills**
#
# **Machine Learning and Deep Learning**
#
# * Supervised Learning: Linear Regression, Logistic Regression, SVM, Decision-Tree, and Ensembles
# * Unsupervised Learning: K-Means, Hierarchical Clustering, and Dimensionality Reduction (Principal Component Analysis)
# * Neural Networks: ANN, CNN, and RNN
# * Deep Learning Frameworks: TensorFlow and Keras
# * NLP
#
# **Data Science**
#
# * Data Analysis & Visualization
# * Statistical Analysis & Modeling
# * Feature Engineering & Optimization Techniques
# * MLOps: MLflow, Packaging, Version Control (Git), Docker, Jenkins, Prometheus, and CI/CD Pipeline
#
# **Web Development, Programming Languages & Databases**
#
# * Web Frameworks: Flask, FastAPI, Django
# * Programming Languages: Python
# * Databases: MySQL
# * Version Control & CI/CD (Basics)
#
# **Cloud and Auxiliary Skills**
#
# * Amazon Web Services (EC2, S3, SageMaker, and others)
# * MLOps: DSA (Basics), MLflow, Packaging, and Version Control (Git)
# * Engineering & Optimization Techniques
#
# **Hobbies**
#
# * Avid Reader
# * Artist (sketching figures and objects)
# * Strategic Chess Player
# * Video/Board Games
# * Coding
# * Problem-solving
# * Inquisitive Listening
# * Creating Lo-fi tracks for fun on YouTube
#
# **Certifications and Achievements**
#
# * Udemy: Python for Data Science and Machine Learning Bootcamp
# * Kaggle: Beginner and Intermediate Machine Learning
# * Udemy: Python Data Structures and Algorithm
# * Udemy: Amazon Web Services - Solution Architect
# * HackerRank: SQL Basic and Intermediate
# * Ranked 1st in chess competitions during the 2nd and 3rd years of my academic journey.
#
# **Contact**
#
# * Email: adi.pandagle@gmail.com
# * Phone: +91 79725 67926
# * LinkedIn: [link]
# * GitHub: [link]
# `

# %%
result

# %%
jd_input = input(str())
# print(jd_input)

get_llama_assistance(f'''Using this JD [{jd_input}]
                     
                     with this Resume [{all_text}]
                     
                     Can you please tell me if the JD matches the Resume, also highlight work location and the score outta 10''')
# Out:
# `
# Based on the Job Description (JD) and the Resume, here's my analysis:
#
# **Matching skills and qualifications:**
#
# * The JD specifies a Bachelor's degree in Computer Science, Artificial Intelligence, or a related field, which the candidate's resume fulfills with a Post-Graduation Program in Data Science and Analytics and a Bachelor's in Business Administration (Computer Application).
# * The JD requires good understanding of machine learning concepts, which the candidate's resume showcases with experience in Machine Learning, Deep Learning, and Generative AI.
# * The JD emphasizes the need for AI ethics, Responsible AI, and transparent AI systems, which is not explicitly mentioned in the candidate's resume, but their exposure to diverse projects and MLOps skills might be relevant to the role.
#
# **Mismatched skills and qualifications:**
#
# * The JD indicates a focus on Responsible AI, AI ethics, and transparency, which is not explicitly mentioned in the candidate's resume.
# * The candidate's resume highlights expertise in MLOps, Generative-AI, and Web Development, which might be secondary skills for the ML Engineer – AI Ethics role.
#
# **Work location:** Not specified in the JD, which implies that it might be a remote or flexible work arrangement.
#
# **Score out of 10:** 7/10
#
# The candidate's resume showcases a strong background in machine learning, deep learning, and MLOps, which aligns with some requirements of the ML Engineer – AI Ethics role. However, the JD's emphasis on Responsible AI, AI ethics, and transparency might not be directly addressed in the candidate's resume. If the candidate is willing to learn and adapt to the specific requirements of the role, they could be a good fit.
# `

# %%
get_llama_assistance(''''Dance of Piano' can you give me better alternatives for this?''')
# Out:
# `
# While "Dance of Piano" is a nice phrase, it may not be conveying the exact message you intend. Here are some alternative phrases that might better capture the essence of what you're trying to express:
#
# 1. **Piano Concerto**: This phrase emphasizes the musical performance aspect, implying a danced movement quality in the way the piano is played.
# 2. **Keyboard Virtuosity**: This phrase highlights the impressive technical skill of the pianist, evoking a sense of dynamic movement in their playing.
# 3. **Rhythmic Fusion**: This phrase suggests a blending of rhythms, creating a sense of dynamic energy and movement, reminiscent of dance.
# 4. **Piano Dynamics**: This phrase captures the contrasting rhythmic and melodic elements in piano music, implying a sense of dynamic movement and energy.
# 5. **Symphony of Fingers**: This phrase beautifully conveys the pianist's dexterity and agility, likening their finger movements to a choreographed dance.
#
# Which of these alternatives resonates with you, or would you like me to explore more options?
# `
