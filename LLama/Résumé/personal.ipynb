# %%
import os
import dotenv
from groq import Groq
from IPython.display import display_markdown

dotenv.load_dotenv()
api_key = os.environ.get("GROQ_API_KEY")

if not api_key:
    raise ValueError("GROQ_API_KEY environment variable not set")

# %%
def get_llama_assistance(prompt):
  client = Groq(api_key=api_key)
  completion = client.chat.completions.create(
      model="llama3-70b-8192",
      messages=[
          {
              "role": "user",
              "content": prompt
          },
          {
              "role": "assistant",
              "content": ""
          }
      ],
      temperature=1.4,
      max_tokens=8192,
      top_p=1,
      stream=True,
      stop=None,
  )

  response_text = ""

  for chunk in completion:
    response_text += chunk.choices[0].delta.content or ""

  # Display the formatted response in markdown
  display_markdown(f"`\n{response_text}\n`", raw=True)

# %%
from docx import Document

def extract_text_from_docx(docx_file_path):
    doc = Document(docx_file_path)
    text_content = []
    for paragraph in doc.paragraphs:
        # Remove leading and trailing spaces from each line
        line = paragraph.text.strip()
        if line:  # Check if line is not empty after stripping
            text_content.append(line)
    return '\n'.join(text_content)

# Example usage:
docx_file_path = 'ICR Agreement .docx'
extracted_text = extract_text_from_docx(docx_file_path)
print(extracted_text)
# Out:
# ELIGIBILITY TO APPLY TO IMARTICUS CORPORATE RELATIONS (ICR)
# 1. Students are eligible for placements post-completion of level 2 of the curriculum (Final Mock) or by formal signoff by the faculty and/or program managers
# 2. Trainers will certify students for placement eligibility based on
# Assessment scores
# Mock interviews
# Viva scores
# Soft Skills Trainer sign-off
# Resume Readiness
# Overall, all discipline and conduct
# 3. Minimum overall attendance should be 80%. Students below 80% attendance will not be eligible for placements
# 4. Students should indemnify any administrative formalities and get a clearance from the Imarticus Administration and Finance department.
# AGREEMENT FOR PLACEMENT ASSISTANCE
# This agreement is made on Imarticus Placement Platform: SuperSet
# THIS AGREEMENT, between IMARTICUS and THE STUDENT, witnesses the mutual understanding and acceptance of the following terms
# IMARTICUS will provide the ICR Service to the Student via the SuperSet platform. Emails/mobile notifications and SMS will be sent to the registered email address & mobile number.
# The Student is solely responsible for continuously monitoring the SuperSet account to check positions /vacancies posted by IMARTICUS.
# To apply to the job openings students should log in to their SuperSet account through Laptop/desktop or Mobile App.
# Opportunities will be posted in the Job profile section of SuperSet.
# Each Student from the Placement Assured Program will be given five interview opportunities. If the student fails to be placed after 5 such attempts, he/she needs to go through an assessment and post clearing the assessment only will be rolled out in the placement pool again. For placement assistance programs we will be sharing public and private leads for job assistance
# A student who applies for a position and then backs out at any stage of the process without prior approval from the Placement team will be barred from placements
# A Student who is a “NO SHOW” at any scheduled interview will be barred from applying for any future job opportunities
# The Student is expected to conduct himself/herself ethically. Unethical behaviour such as cheating during the selection process or misrepresentation of facts in a resume will disqualify the student from placement
# As soon as the student receives the offer of employment with an Organization via the ICR service, the ICR service will be considered fulfilled and this contract will expire.
# Post the final mock if a particular student has been graded in T3, he/she doesn’t have an option to apply to the companies of their choice and will have to abide by the drives offered to them. However, a student has an option of improving their grades after another mock (Limited to 2).
# The Student can contact the placement coordinator of the Centre where he/she completed the course whenever he/she requires any clarification about the Organization or the Vacancy
# It shall be the responsibility of the Student to attend the interview on her/his own. Imarticus has no control over the outcome of the interview/selection process. Imarticus shall not be held responsible in the event the Student gets disqualified for selection for any vacancy, whatsoever the reason
# Upon receipt of an offer of employment, the Student will immediately inform IMARTICUS regarding details of her /his appointment and acceptance thereof
# In the event the student has not applied for any position for two months after signing the ICR, they will be contacted by email and phone at least twice to confirm their continued participation in the placement program. In the event of no response or confirmation from the student within three weeks, attempts will be made to contact the student again after which a registered letter will be sent to the permanent address of the Student terminating this contract
# In availing the ICR Service, the student hereby agrees and undertakes that during the period of this agreement and up to a minimum of 18 months from the day and date of signing of this agreement, he/she shall not: -
# (i) Defame IMARTICUS directly or indirectly and/or make any verbal, written or oral statements which can be construed as derogatory/defamatory pertaining to ‘IMARTICUS’ and the ‘COURSES’ conducted by ‘IMARTICUS’
# (ii) Share Course material, manuals, books and or photocopies of the same and/or disclose the same in any other manner, whatsoever to any other person (other than IMARTICUS’s students), organisation, firm, company or any other entity
# (iii) Start competitive activities either himself or through his family members, which includes but is not limited to similar business as that of ‘IMARTICUS’ directly, indirectly or in any manner,  in India and/or Abroad
# (iv) Disclose to any other person, (other than ‘IMARTICUS’s Students) or organisation, firm, company or any entity, whosoever, any information received by him/her from ‘IMARTICUS’ as part of ‘ Assistance Services provided by ‘IMARTICUS CORPORATE RELATIONS”, which includes Offer details, Salary figures but not limited to job vacancies in Investment Banks, KPO’s and other niche organizations in the BFSI domain
# (v) Indulge in any anti ‘IMARTICUS’ activity, whatsoever.
# 16. The original copy of this agreement shall be retained by “IMARTICUS”
# 17. This Agreement shall be construed and interpreted by the laws of India.
# Date :	9th May 2024
# Place:	India, Maharashtra, Pune
# Name :	Aaditya Pandagle
# Permanent Address:	Indrayani HSC Society, Rupeenagar, Talawade-Road, Nigdi-Pune
# Batch No:	PG-WD-47
# Signature :

# %%
cwd = os.getcwd()
path1 = os.path.dirname(cwd)
poppler_path = os.path.join(path1, 'Gemini', 'poppler-24.02.0', 'Library', 'bin')
print(poppler_path)
# Out:
# d:\CODING\Generative-AI\LLama\Gemini\poppler-24.02.0\Library\bin

# %%
# !pip install pdfquery
# !pip install pdfplumber

# %%
import pdfplumber
import re

def clean_text(text):
    # Remove extra newlines and leading/trailing whitespace
    text = re.sub(r'\n\s*\n', '\n\n', text)  # Replace multiple newlines with a single newline
    text = text.strip()  # Remove leading and trailing whitespace
    return text

path = r'Templates\Aaditya_Pandagle_Resume_2024.pdf'

with pdfplumber.open(path) as pdf:
    all_text = ""
    for page in pdf.pages:
        text = page.extract_text()
        if text:
            all_text += text + "\n\n"
            
all_text = clean_text(all_text)
print(all_text)
print(len(all_text))
# Out:
# Work and Projects
# A a d i t y a
# Fresher with a strong theoretical understanding of company systems and operations.
# P a n d a g l e While not having direct work experience, you can explore my GitHub profile where I’ve
# performed statistical analysis and created predictive models. The portfolio spans various
# topics such as:
# Data Science | AI & Machine Learning |
# MLOps Machine Learning:
# Fraud Detection: Identify fraudulent activities within financial transactions using ML
# algorithms on authentic datasets.
# Credit Risk Assessment: Assessing credit risk for loan applicants using predictive
# Contact:
# modelling.
# House Rent Prediction: Using machine learning algorithms to predict house rent
# adi.pandagle@gmail.com
# prices in India.
# +91 79725 67926 Customer Discount Offering Prediction: Predict which customers will likely receive
# discounts for targeted marketing.
# LinkedIn and GitHub link Salary Prediction: Predicting individual salaries based on demographic and
# employment details.
# Education: Deep Learning:
# American Sign Language Detection: Developed a model to recognize and interpret
# Post Graduation Program in Data Science
# American Sign Language gestures for communication accessibility.
# and Analytics - Imarticus Learning (Pune)
# (2023 - 2024) Others:
# Django: Utilized Django to create a web-based diabetes prediction model.
# Bachelors' in Business Administration OCR-Gemini: Leveraged Tesseract for invoice text extraction and Gemini for data
# (Computer Application) Modern College of structuring the extracted data into JSON format.
# Commerce & Computer Studies; Savitribai MLOps Sandbox: MLOps Integration Testing (Docker, Jenkins, CI/CD)
# Phule Pune University Affiliated.
# (2020 - 2023) CGPA - 8.61 Certifications and Achievemnets
# Udemy: Python for Data Science and Machine Learning Bootcamp
# Senior Secondary School - PDEA's Shri
# Kaggle - Beginner and Intermediate Machine Learning
# Mhalsakant Vidyalaya & Jr. College.
# HackerRank - SQL Basic and Intermediate
# (2018 - 2020) - 55.69%
# Udemy: Python Data Structures and Algorithm
# Udemy: Amazon Web Services - Solution Architect.
# High School - S.P.M English Medium
# Ranked 1st in chess competitions during both the 2nd and 3rd years of my
# School, Nigdi-Pune.
# academic journey.
# (2007 - 2018) - 69.00%
# Skills & Hobbies
# Auxilary Skills:
# Machine Learning and Deep Learning:
# DSA (Basics)
# Supervised Learning: (Linear & Logistics Regression, SVM, Decision-Tree and
# Cloud (AWS) Ensembles)
# Deep Learning (Fundamentals) Unsupervised Learning (K-Means, Hierarchical Clustering, and Dimensionality
# Reduction-Principal Component Analysis)
# Packaging & Containerization
# Neural Networks (CNN), NLP, and DL Frameworks (TensorFlow and Keras)
# Version Control Deployment & CI/CD Data Science:
# (Basics) Data Analysis & Visualization, Statistical Analysis & Modeling, Feature
# Engineering & Optimization Techniques.
# Collaborative and Adaptability
# MLOps:
# Problem-solving and Critical Thinking MLflow, Packaging, Version Control (Git), Docker, Jenkins, Prometheus and
# Inquisitive CI/CD Pipeline.
# Web Development, Programming Languages & Databases:
# Flask, FastAPI, Django, Data Structures & Algorithms (DSA), Python and
# MySQL
# Languages:
# Cloud:
# Amazon Web Services (EC2, S3, SageMaker, and others)
# English
# Hobbies
# Hindi and Marathi (Native)
# Avid Reader, Artist (sketching figures and objects)
# German, Spanish and Japanese
# Strategic Chess Player, Video/Board Games, Coding.
# (Novice) Listening and Creating Lo-fi tracks for fun on YouTube
# 3457

# %%
path = r'Templates\Aaditya_Pandagle_Resume_2024.pdf'

with pdfplumber.open(path) as pdf:
  all_text = ""
  # Below is for storing the extracted data in list 
  # extracted_text = []
  for page in pdf.pages:
    all_text += page.extract_text() + "\n\n"
    # extracted_text.append(page.extract_text()) 
    
print(all_text)
print(len(all_text))
# Out:
# Work and Projects
# A a d i t y a
# Fresher with a strong theoretical understanding of company systems and operations.
# P a n d a g l e While not having direct work experience, you can explore my GitHub profile where I’ve
# performed statistical analysis and created predictive models. The portfolio spans various
# topics such as:
# Data Science | AI & Machine Learning |
# MLOps Machine Learning:
# Fraud Detection: Identify fraudulent activities within financial transactions using ML
# algorithms on authentic datasets.
# Credit Risk Assessment: Assessing credit risk for loan applicants using predictive
# Contact:
# modelling.
# House Rent Prediction: Using machine learning algorithms to predict house rent
# adi.pandagle@gmail.com
# prices in India.
# +91 79725 67926 Customer Discount Offering Prediction: Predict which customers will likely receive
# discounts for targeted marketing.
# LinkedIn and GitHub link Salary Prediction: Predicting individual salaries based on demographic and
# employment details.
# Education: Deep Learning:
# American Sign Language Detection: Developed a model to recognize and interpret
# Post Graduation Program in Data Science
# American Sign Language gestures for communication accessibility.
# and Analytics - Imarticus Learning (Pune)
# (2023 - 2024) Others:
# Django: Utilized Django to create a web-based diabetes prediction model.
# Bachelors' in Business Administration OCR-Gemini: Leveraged Tesseract for invoice text extraction and Gemini for data
# (Computer Application) Modern College of structuring the extracted data into JSON format.
# Commerce & Computer Studies; Savitribai MLOps Sandbox: MLOps Integration Testing (Docker, Jenkins, CI/CD)
# Phule Pune University Affiliated.
# (2020 - 2023) CGPA - 8.61 Certifications and Achievemnets
# Udemy: Python for Data Science and Machine Learning Bootcamp
# Senior Secondary School - PDEA's Shri
# Kaggle - Beginner and Intermediate Machine Learning
# Mhalsakant Vidyalaya & Jr. College.
# HackerRank - SQL Basic and Intermediate
# (2018 - 2020) - 55.69%
# Udemy: Python Data Structures and Algorithm
# Udemy: Amazon Web Services - Solution Architect.
# High School - S.P.M English Medium
# Ranked 1st in chess competitions during both the 2nd and 3rd years of my
# School, Nigdi-Pune.
# academic journey.
# (2007 - 2018) - 69.00%
# Skills & Hobbies
# Auxilary Skills:
# Machine Learning and Deep Learning:
# DSA (Basics)
# Supervised Learning: (Linear & Logistics Regression, SVM, Decision-Tree and
# Cloud (AWS) Ensembles)
# Deep Learning (Fundamentals) Unsupervised Learning (K-Means, Hierarchical Clustering, and Dimensionality
# Reduction-Principal Component Analysis)
# Packaging & Containerization
# Neural Networks (CNN), NLP, and DL Frameworks (TensorFlow and Keras)
# Version Control Deployment & CI/CD Data Science:
# (Basics) Data Analysis & Visualization, Statistical Analysis & Modeling, Feature
# Engineering & Optimization Techniques.
# Collaborative and Adaptability
# MLOps:
# Problem-solving and Critical Thinking MLflow, Packaging, Version Control (Git), Docker, Jenkins, Prometheus and
# Inquisitive CI/CD Pipeline.
# Web Development, Programming Languages & Databases:
# Flask, FastAPI, Django, Data Structures & Algorithms (DSA), Python and
# MySQL
# Languages:
# Cloud:
# Amazon Web Services (EC2, S3, SageMaker, and others)
# English
# Hobbies
# Hindi and Marathi (Native)
# Avid Reader, Artist (sketching figures and objects)
# German, Spanish and Japanese
# Strategic Chess Player, Video/Board Games, Coding.
# (Novice) Listening and Creating Lo-fi tracks for fun on YouTube
#
#
# 3459

# %%
aaaa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 aaaa
#
# NameError: name 'aaaa' is not defined

# %%
get_llama_assistance(f'''I need your help to organize the Resume text, I extracted from a PDF:
                    {all_text}''')
# Out:
# `
# I'd be happy to help you organize the resume text. Here is a reorganized version, categorized into clear sections:
#
# **Contact Information**
#
# * Email: [adi.pandagle@gmail.com](mailto:adi.pandagle@gmail.com)
# * Phone: +91 79725 67926
# * LinkedIn: [Insert LinkedIn link]
# * GitHub: [Insert GitHub link]
#
# **Summary**
# Fresher with a strong theoretical understanding of company systems and operations.
#
# **Education**
#
# * Post Graduation Program in Data Science and Analytics, Imarticus Learning (Pune), 2023-2024
# * Bachelors' in Business Administration (Computer Application), Modern College of Commerce & Computer Studies; Savitribai Phule Pune University, 2020-2023
# * Senior Secondary School - PDEA's Shri Mhalsakant Vidyalaya & Jr. College, 2018-2020
# * High School - S.P.M English Medium School, Nigdi-Pune, 2007-2018
#
# **Certifications and Achievements**
#
# * Udemy: Python for Data Science and Machine Learning Bootcamp
# * Kaggle: Beginner and Intermediate Machine Learning
# * HackerRank: SQL Basic and Intermediate
# * Udemy: Python Data Structures and Algorithm
# * Udemy: Amazon Web Services - Solution Architect
# * Ranked 1st in chess competitions during both the 2nd and 3rd years of my academic journey.
#
# **Skills**
#
# **Machine Learning and Deep Learning**
#
# * Supervised Learning: Linear & Logistics Regression, SVM, Decision-Tree, and Ensembles
# * Unsupervised Learning: K-Means, Hierarchical Clustering, and Dimensionality Reduction-Principal Component Analysis
# * Deep Learning: Neural Networks (CNN), NLP, and DL Frameworks (TensorFlow and Keras)
#
# **Cloud and MLOps**
#
# * Cloud (AWS)
# * MLOps: MLflow, Packaging, Version Control (Git), Docker, Jenkins, Prometheus, and CI/CD Pipeline
# * Packaging & Containerization
#
# **Data Science**
#
# * Data Analysis & Visualization
# * Statistical Analysis & Modeling
# * Feature Engineering & Optimization Techniques
# * Problem-solving and Critical Thinking
#
# **Web Development, Programming Languages, and Databases**
#
# * Flask, FastAPI, Django
# * Data Structures & Algorithms (DSA)
# * Python
# * MySQL
#
# **Languages**
#
# * English
# * Hindi and Marathi (Native)
# * German, Spanish, and Japanese (Novice)
#
# **Hobbies**
#
# * Avid Reader, Artist (sketching figures and objects)
# * Strategic Chess Player, Video/Board Games, Coding
# * Listening and Creating Lo-fi tracks for fun on YouTube
# `

# %%
jd_input = input(str())

# %%
print(jd_input)
# Out:
# Working with Us Challenging. Meaningful. Life-changing. Those aren't words that are usually associated with a job. But working at Bristol Myers Squibb is anything but usual. Here, uniquely interesting work happens every day, in every department. From optimizing a production line to the latest breakthroughs in cell therapy, this is work that transforms the lives of patients, and the careers of those who do it. You'll get the chance to grow and thrive through opportunities uncommon in scale and scope, alongside high-achieving teams rich in diversity. Take your career farther than you thought possible.  Bristol Myers Squibb recognizes the importance of balance and flexibility in our work environment. We offer a wide variety of competitive benefits, services and programs that provide our employees with the resources to pursue their goals, both at work and in their personal lives. Read more: careers.bms.com/working-with-us .  BMS Hyderabad is an integrated global hub where our work is focused on helping patients prevail over serious diseases by building sustainable and innovative solutions. This important science, technology, and innovation center will support a range of technology and drug development activities that will help us usher in the next wave of innovation.  Summary: The Data Scientist position is a specialized role within BIA Hyderabad. They will focus on applying advanced statistical and machine learning techniques to extract insights from complex data sets and drive data-driven decision-making processes. The Data Scientist will collaborate with cross-functional teams, conduct in-depth analysis, develop predictive models, and provide actionable recommendations to enhance business performance and drive innovation.  Roles & Responsibilities  Collaborate with stakeholders to define project objectives, formulate data-driven hypotheses and identify KPIs for analysis Gather, pre-process and explore large-scale structured and unstructured data from diverse sources, including clinical trials, patient records and genetic data Apply advanced statistical analysis, machine learning algorithms and predictive modelling techniques to extract insights and develop models that drive actionable recommendations Conduct exploratory data analysis (EDA) to identify patterns and anomalies in the data and propose solutions to business problems Partner with senior data scientists to develop and implement predictive models (e.g., regression, clustering, time series forecasting) to solve complex business challenges Collaborate with data engineers and IT teams to ensure data availability, quality and reliability for analysis and modeling Communicate complex analytical findings and insights to both technical and non-technical stakeholders through clear and compelling visualizations, reports and presentations Stay up-to-date with the latest methodologies and best practices in statistical analysis and machine learning  Skills and competencies • Proficiency in programming languages such as Python or R for data manipulation, analysis and modeling Experience with building and deploying data science and data engineering solutions using established industry methods ( MLOps , Git) to pharmaceutical related datasets is preferred Familiarity with data visualization tools such as Tableau, Power BI or matplotlib/seaborn for effective communication of finding Strong understanding of experimental design, hypothesis testing and A/B testing methodologies Solid problem-solving skills and the ability to think critically and creatively to tackle complex business challenges Solid communication and presentation skills to convey complex concepts to technical and non-technical stakeholders Familiarity with cloud platforms (e.g., AWS, Azure) and big data technologies (e.g., Hadoop, Spark) is a plus Strong organizational and time management skills, with the ability to prioritize tasks and meet deadlines in a fast-paced environment  Experience :-  We welcome a bachelor's or ...

# %%
get_llama_assistance(f'''Can you compare this JD {jd_input}
                     
                     with this Resume {all_text}
                     
                     Help me identify what am I missing, what can be improved, as if you're a Master''')
# Out:
# `
# Let's examine your resume and the job description, and I'll provide you with a thorough analysis, as if I were a Master. 😇
#
# **Comparison of your resume with the job description:**
#
# 1. **Data Science Skills:** Your resume showcases a good balance of theoretical knowledge and practical experience in data science, machine learning, and MLOps. You've highlighted various projects, certifications, and skills relevant to the job. However, the job description emphasizes "advanced statistical analysis" and "predictive modeling techniques," which might require more explicit mentioning in your resume.
# 2. **Lack of Industry Experience:** While you've compensated for the lack of direct work experience with a strong portfolio on GitHub, the job description explicitly mentions "0 to 3 years of experience in a data science role, preferably within the biopharma or pharmaceutical industry." This might be a gap in your resume.
# 3. **Domain Knowledge:** The job description focusses on pharmaceuticals and working with healthcare data. Your resume doesn't explicitly demonstrate experience or knowledge in this domain. You might consider adding relevant coursework, certifications, or side projects that showcase your understanding of the pharmaceutical industry.
#
# **Suggestions for improvement:**
#
# 1. **Tailor your resume:** Customize your resume to highlight skills and experiences that closely match the requirements of the job description.
# 2. **Emphasize expertise in statistical analysis:** Consider adding more details about your statistical analysis skills, including regression analysis, hypothesis testing, and experimentation design.
# 3. **Include domain-specific experience or knowledge:** If you have any coursework, projects, or certifications related to pharmaceuticals or healthcare data, add them to your resume to demonstrate domain knowledge.
# 4. **Quantify achievements:** Consider adding metrics or accomplishments to your portfolio projects to provide more context to the recruiter.
# 5. **Visuals and verbosity:** Your resume has a lot of information condensed into short paragraphs. Consider using bullet points and shorter sentences to improve readability.
#
# **Other suggestions:**
#
# 1. **Social media profiles:** Ensure your LinkedIn profile is up-to-date and aligned with your resume.
# 2. **Research the company:** Show your interest in Bristol Myers Squibb by researching the company culture, mission, and values, and how your skills align with their goals.
#
# Now, go forth and address these points to make your resume shine! 💫
# `
